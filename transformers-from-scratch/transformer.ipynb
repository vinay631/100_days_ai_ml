# %%
# !pip install ipywidgets
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ...

# %%
from transformers import AutoTokenizer
from bertviz.transformers_neuron_view import BertModel
from bertviz.neuron_view import show

model_ckpt = "bert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(model_ckpt)
model = BertModel.from_pretrained(model_ckpt)
text = "time flies like an arrow"
show(model, "bert", tokenizer, text, display_mode="light", layer=0, head=8)
# Out:
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"></script>
#         <div id=bertviz-d710149eb7de4ebc81418e83f3452bcb style="padding:8px;font-family:'Helvetica Neue', Helvetica, Arial, sans-serif;">
#           <span style="user-select:none">
#             <span class="dropdown-label">Layer: </span><select id="layer"></select>
#             <span class="dropdown-label">Head: </span> <select id="att_head"></select>
#
#           </span>
#           <div id='vis'></div>
#         </div>

# %%
inputs = tokenizer(text, return_tensors="pt", add_special_tokens=False)
inputs.input_ids
# Out:
# tensor([[ 2051, 10029,  2066,  2019,  8612]])

# %% [markdown]
# ## Create dense embeddings
# Dense - each entry in embedding contains a nonzero value
# `Autoconfig` class to load the _config.json_ file associated with the model

# %%
from torch import nn
from transformers import AutoConfig

config = AutoConfig.from_pretrained(model_ckpt)
token_emb = nn.Embedding(config.vocab_size, config.hidden_size)
token_emb
# Out:
# Embedding(30522, 768)

# %% [markdown]
# ## Generate embeddings
# Note - this embedding doesn't have context

# %%
inputs_embeds = token_emb(inputs.input_ids)
inputs_embeds.size()
# Out:
# torch.Size([1, 5, 768])

# %% [markdown]
# ## Create query, key, value vectors

# %%
import torch
from math import sqrt

query = key = value = inputs_embeds
dim_k = key.size(-1)
scores = torch.bmm(query, key.transpose(1, 2)) / sqrt(dim_k) # bmm - batch matrix matrix product. Still don't understand
scores.size()
# Out:
# torch.Size([1, 5, 5])

# %% [markdown]
# ## Apply Softmax

# %%
import torch.nn.functional as F

weights = F.softmax(scores, dim=-1)
weights.sum(dim=-1)
# Out:
# tensor([[1., 1., 1., 1., 1.]], grad_fn=<SumBackward1>)

# %%
# Multiply attention weights by the values
attn_outputs = torch.bmm(weights, value)
attn_outputs.shape
# Out:
# torch.Size([1, 5, 768])

# %% [markdown]
# ## Create a function for self attention

# %%
def scaled_dot_product_attention(query, key, value):
    dim_k = query.size(-1)
    scores = torch.bmm(query, key.transpose(1, 1)) / sqrt(dim_k)
    weights = F.softmax(scores, dim=-1)
    return torch.bmm(weights, value)

# %% [markdown]
# ## Multi-headed attention
# Multi-headed attention layer similar to filters in CNN where one filter can be responsible for detecting faces and another for finding wheels of cars in image. Each head captures different aspect of similarity. One head can can focus on subject-verb interaction, another can find nearby adjectives

# %%
class AttentionHead(nn.Module):
    def __init__(self, embed_dim, head_dim):
        super().__init__()
        self.q = nn.Linear(embed_dim, head_dim)
        self.k = nn.Linear(embed_dim, head_dim)
        self.v = nn.Linear(embed_dim, head_dim)

    def forward(self, hidden_state):
        attn_outputs = scaled_dot_product_attention(
            self.q(hidden_state), self.k(hidden_state), self.v(hidden_state))
        return attn_outputs

# %%
nn.Linear(20, 8)(7)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 nn.Linear(20, 8)(7)
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
# ...
